# %%
import pandas as pd
import os
import shutil

# %%
File_path = "C:/Users/sanju/Desktop/dee/covid-chestxray-dataset-master/covid/metadata.csv"
Image_path = "C:/Users/sanju/Desktop/dee/covid-chestxray-dataset-master/covid/images"

# %%
df = pd.read_csv(File_path)
print(df.shape)
# Out:
# (950, 30)

# %%
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
Target_dir = "Dataset/covid"

if not os.path.exists(Target_dir):
    os.mkdir(Target_dir)
    print ("covid folder created")

# %%
cnt = 0

for (i, row) in df.iterrows():
    if row["finding"] == "Pneumonia/Viral/COVID-19" and row["view"]== "PA" or row["finding"]== "Pneumonia/Viral/SARS":
        filename = row["filename"]
        image_path = os.path.join(Image_path, filename)
        image_copy_path = os.path.join(Target_dir, filename)
        shutil.copy2(image_path, image_copy_path)
        print("data copy",i)
        cnt += 1
        
print (cnt)
# Out:
# data copy 0
# data copy 1
# data copy 2
# data copy 3
# data copy 4
# data copy 5
# data copy 7
# data copy 8
# data copy 9
# data copy 10
# data copy 11
# data copy 12
# data copy 13
# data copy 14
# data copy 15
# data copy 16
# data copy 17
# data copy 18
# data copy 19
# data copy 20
# data copy 21
# data copy 22
# data copy 24
# data copy 26
# data copy 27
# data copy 29
# data copy 30
# data copy 31
# data copy 32
# data copy 33
# data copy 39
# data copy 48
# data copy 51
# data copy 54
# data copy 72
# data copy 81
# data copy 82
# data copy 88
# data copy 90
# data copy 91
# data copy 92
# data copy 93
# data copy 95
# data copy 96
# data copy 98
# data copy 99
# data copy 101
# data copy 103
# data copy 107
# data copy 110
# data copy 111
# data copy 115
# data copy 116
# data copy 117
# data copy 118
# data copy 129
# data copy 130
# data copy 131
# data copy 132
# data copy 133
# data copy 134
# data copy 136
# data copy 142
# data copy 143
# data copy 146
# ...
